# %% [markdown]
# #  파일 불러오기
# - csv 파일, 엑셀 파일
# - output/ 폴더에 있는 result.csv 파일,
# result.xlsx 파일 불러오기
# - 공식 문서 : https://pandas.pydata.org/docs/user_guide/io.html/

# %%
# 구글 드라이브와 연결
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

DATA_PATH = '/content/drive/MyDrive/Colab Notebooks/2026/이어드림스쿨6기/4주차/02_pandas와데이터시각화/output/'

df = pd.read_csv(DATA_PATH + 'result.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62 entries, 0 to 61
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  62 non-null     float64
#  1   tip         62 non-null     float64
#  2   sex         62 non-null     object
#  3   smoker      62 non-null     object
#  4   day         62 non-null     object
#  5   time        62 non-null     object
#  6   size        62 non-null     int64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 3.5+ KB

# %%
# Returns a DataFrame
df2 = pd.read_excel(DATA_PATH + 'result.xlsx', sheet_name="tips")
df2.head()
# Out:
#    Unnamed: 0  total_bill   tip     sex smoker  day    time  size
# 0           0       21.01  3.50    Male     No  Sun  Dinner     3
# 1           1       24.59  3.61  Female     No  Sun  Dinner     4
# 2           2       25.29  4.71    Male     No  Sun  Dinner     4
# 3           3       26.88  3.12    Male     No  Sun  Dinner     4
# 4           4       35.26  5.00  Female     No  Sun  Dinner     4
